# %% [markdown]
# # 导入所需的库

# %%
import requests
import certifi # 用于验证证书
import pandas as pd
import time

from ratelimit import limits, sleep_and_retry
from requests.exceptions import RequestException

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1 定义获取函数

# %%
# Binance API 限制：5 分钟最多 500 次请求
FIVE_MINUTES = 300  # 5 分钟 = 300 秒
MAX_REQUESTS = 500  # Binance 允许的最大请求数

@sleep_and_retry
@limits(calls=MAX_REQUESTS, period=FIVE_MINUTES)
def get_funding_rate_history_chunk(symbol, start_ts, endpoint_url, limit=1000, verify=True):
    """
    获取最多 limit 条资金费率数据，从 start_ts 开始，带有 API 限流控制和指数退避重试机制。
    """
    params = {
        "symbol": symbol,
        "limit": limit,
        "startTime": start_ts,
    }

    retries = 10 # 最大重试次数
    delay = 2 # 初始等待2s（指数退避）

    for attempt in range(retries):
        try:
            response = requests.get(endpoint_url, params=params, verify=verify)
            response.raise_for_status()  # 如果返回 429、5xx 或其他错误，会抛出异常
            data = response.json()
            return data  # 成功请求则直接返回数据
        
        except RequestException as e:
            print(f"[第 {attempt+1} 次失败] 请求错误：{e}，等待 {delay} 秒后重试...")
            time.sleep(delay)
            delay *= 2  # 指数退避：2s -> 4s -> 8s -> 16s -> ...

    # 如果循环结束还没成功，抛出异常
    raise Exception(f"连续 {retries} 次请求失败，终止请求。")

def get_full_funding_rate_history(symbol, endpoint_url="https://fapi.binance.com/fapi/v1/fundingRate", verify=True):
    """
    以 `limit=1000` 条为单位进行翻页，获取完整的资金费率数据。
    """
    all_data = []
    
    # 可以从交易所上线日期、或只从 2020年 开始；如果想拿尽量早，可以写死一个日期
    start_ts = 1586908800000  # 这里是 2020-04-15 00:00:00 (ms)
    now_ts = int(time.time() * 1000)
    
    # 用 while 循环不断地往后翻，直到超过当前时间
    while start_ts < now_ts:
        data_part = get_funding_rate_history_chunk(symbol, start_ts, endpoint_url, limit=1000, verify=verify)

        if not data_part:
            break # 如果没有数据返回，说明到头了
    
        # 合并到 all_data
        all_data.extend(data_part)
        
        # 如果返回的数据不足 1000 条，说明没有更多数据
        if len(data_part) < 1000:
            break

        # 获取最后一条数据的时间戳，并 +1，作为下一次查询的起始时间
        start_ts = data_part[-1]["fundingTime"] + 1
    
    return all_data

# %% [markdown]
# # 2 获取所有币对信息， 并遍历所有币对，采集资金费率历史数据

# %%
exchange_info_url = "https://fapi.binance.com/fapi/v1/exchangeInfo"
try:
    response = requests.get(exchange_info_url, verify=certifi.where())
except Exception as e:
    print(f"获取币对信息时发生异常：{e}")
    response = None

if response is None or response.status_code != 200:
    raise Exception("无法获取币对信息，请检查网络或 API 状态。")

exchange_data = response.json()
# 筛选出状态为 TRADING 且合约类型为 PERPETUAL 的币对
symbols = [s["symbol"] for s in exchange_data["symbols"]
           if s.get("contractType") == "PERPETUAL" and s.get("status") == "TRADING"]

print(f"共获取到 {len(symbols)} 个币对：")
print(symbols)
# Out:
# 共获取到 386 个币对：
# ['BTCUSDT', 'ETHUSDT', 'BCHUSDT', 'XRPUSDT', 'EOSUSDT', 'LTCUSDT', 'TRXUSDT', 'ETCUSDT', 'LINKUSDT', 'XLMUSDT', 'ADAUSDT', 'XMRUSDT', 'DASHUSDT', 'ZECUSDT', 'XTZUSDT', 'BNBUSDT', 'ATOMUSDT', 'ONTUSDT', 'IOTAUSDT', 'BATUSDT', 'VETUSDT', 'NEOUSDT', 'QTUMUSDT', 'IOSTUSDT', 'THETAUSDT', 'ALGOUSDT', 'ZILUSDT', 'KNCUSDT', 'ZRXUSDT', 'COMPUSDT', 'DOGEUSDT', 'SXPUSDT', 'KAVAUSDT', 'BANDUSDT', 'RLCUSDT', 'MKRUSDT', 'SNXUSDT', 'DOTUSDT', 'DEFIUSDT', 'YFIUSDT', 'BALUSDT', 'CRVUSDT', 'TRBUSDT', 'RUNEUSDT', 'SUSHIUSDT', 'EGLDUSDT', 'SOLUSDT', 'ICXUSDT', 'STORJUSDT', 'UNIUSDT', 'AVAXUSDT', 'ENJUSDT', 'FLMUSDT', 'KSMUSDT', 'NEARUSDT', 'AAVEUSDT', 'FILUSDT', 'RSRUSDT', 'LRCUSDT', 'BELUSDT', 'AXSUSDT', 'ALPHAUSDT', 'ZENUSDT', 'SKLUSDT', 'GRTUSDT', '1INCHUSDT', 'CHZUSDT', 'SANDUSDT', 'ANKRUSDT', 'RVNUSDT', 'SFPUSDT', 'COTIUSDT', 'CHRUSDT', 'MANAUSDT', 'ALICEUSDT', 'HBARUSDT', 'ONEUSDT', 'LINAUSDT', 'STMXUSDT', 'DENTUSDT', 'CELRUSDT', 'HOTUSDT', 'MTLUSDT', 'OGNUSDT', 'NKNUSDT', '1000SHIBUSDT', 'BAKEUSDT', 'GTCUSDT', 'BTCDOMUSDT', 'IOTXUSDT', 'C98USDT', 'MASKUSDT', 'ATAUSDT', 'DYDXUSDT', '1000XECUSDT', 'GALAUSDT', 'CELOUSDT', 'ARUSDT', 'ARPAUSDT', 'CTSIUSDT', 'LPTUSDT', 'ENSUSDT', 'PEOPLEUSDT', 'ROSEUSDT', 'DUSKUSDT', 'FLOWUSDT', 'IMXUSDT', 'API3USDT', 'GMTUSDT', 'APEUSDT', 'WOOUSDT', 'JASMYUSDT', 'OPUSDT', 'INJUSDT', 'STGUSDT', 'SPELLUSDT', '1000LUNCUSDT', 'LUNA2USDT', 'LDOUSDT', 'ICPUSDT', 'APTUSDT', 'QNTUSDT', 'FETUSDT', 'FXSUSDT', 'HOOKUSDT', 'MAGICUSDT', 'TUSDT', 'HIGHUSDT', 'MINAUSDT', 'ASTRUSDT', 'PHBUSDT', 'GMXUSDT', 'CFXUSDT', 'STXUSDT', 'BNXUSDT', 'ACHUSDT', 'SSVUSDT', 'CKBUSDT', 'PERPUSDT', 'TRUUSDT', 'LQTYUSDT', 'USDCUSDT', 'IDUSDT', 'ARBUSDT', 'JOEUSDT', 'TLMUSDT', 'AMBUSDT', 'LEVERUSDT', 'RDNTUSDT', 'HFTUSDT', 'XVSUSDT', 'ETHBTC', 'BLURUSDT', 'EDUUSDT', 'SUIUSDT', '1000PEPEUSDT', '1000FLOKIUSDT', 'UMAUSDT', 'COMBOUSDT', 'NMRUSDT', 'MAVUSDT', 'XVGUSDT', 'WLDUSDT', 'PENDLEUSDT', 'ARKMUSDT', 'AGLDUSDT', 'YGGUSDT', 'DODOXUSDT', 'BNTUSDT', 'OXTUSDT', 'SEIUSDT', 'CYBERUSDT', 'HIFIUSDT', 'ARKUSDT', 'BICOUSDT', 'BIGTIMEUSDT', 'WAXPUSDT', 'BSVUSDT', 'RIFUSDT', 'POLYXUSDT', 'GASUSDT', 'POWRUSDT', 'TIAUSDT', 'CAKEUSDT', 'MEMEUSDT', 'TWTUSDT', 'TOKENUSDT', 'ORDIUSDT', 'STEEMUSDT', 'BADGERUSDT', 'ILVUSDT', 'NTRNUSDT', 'KASUSDT', 'BEAMXUSDT', '1000BONKUSDT', 'PYTHUSDT', 'SUPERUSDT', 'USTCUSDT', 'ONGUSDT', 'ETHWUSDT', 'JTOUSDT', '1000SATSUSDT', 'AUCTIONUSDT', '1000RATSUSDT', 'ACEUSDT', 'MOVRUSDT', 'NFPUSDT', 'BTCUSDC', 'ETHUSDC', 'BNBUSDC', 'SOLUSDC', 'XRPUSDC', 'AIUSDT', 'XAIUSDT', 'DOGEUSDC', 'WIFUSDT', 'MANTAUSDT', 'ONDOUSDT', 'LSKUSDT', 'ALTUSDT', 'JUPUSDT', 'ZETAUSDT', 'RONINUSDT', 'DYMUSDT', 'SUIUSDC', 'OMUSDT', 'LINKUSDC', 'PIXELUSDT', 'STRKUSDT', 'ORDIUSDC', 'GLMUSDT', 'PORTALUSDT', 'TONUSDT', 'AXLUSDT', 'MYROUSDT', '1000PEPEUSDC', 'METISUSDT', 'AEVOUSDT', 'WLDUSDC', 'VANRYUSDT', 'BOMEUSDT', 'ETHFIUSDT', 'AVAXUSDC', '1000SHIBUSDC', 'ENAUSDT', 'WUSDT', 'WIFUSDC', 'BCHUSDC', 'TNSRUSDT', 'SAGAUSDT', 'LTCUSDC', 'NEARUSDC', 'TAOUSDT', 'OMNIUSDT', 'ARBUSDC', 'NEOUSDC', 'FILUSDC', 'TIAUSDC', 'BOMEUSDC', 'REZUSDT', 'ENAUSDC', 'ETHFIUSDC', '1000BONKUSDC', 'BBUSDT', 'NOTUSDT', 'TURBOUSDT', 'IOUSDT', 'ZKUSDT', 'MEWUSDT', 'LISTAUSDT', 'ZROUSDT', 'CRVUSDC', 'RENDERUSDT', 'BANANAUSDT', 'RAREUSDT', 'GUSDT', 'SYNUSDT', 'SYSUSDT', 'VOXELUSDT', 'BRETTUSDT', 'ALPACAUSDT', 'POPCATUSDT', 'SUNUSDT', 'VIDTUSDT', 'NULSUSDT', 'DOGSUSDT', 'MBOXUSDT', 'CHESSUSDT', 'FLUXUSDT', 'BSWUSDT', 'QUICKUSDT', 'NEIROETHUSDT', 'RPLUSDT', 'AERGOUSDT', 'POLUSDT', 'UXLINKUSDT', '1MBABYDOGEUSDT', 'NEIROUSDT', 'KDAUSDT', 'FIDAUSDT', 'FIOUSDT', 'CATIUSDT', 'GHSTUSDT', 'LOKAUSDT', 'HMSTRUSDT', 'REIUSDT', 'COSUSDT', 'EIGENUSDT', 'DIAUSDT', '1000CATUSDT', 'SCRUSDT', 'GOATUSDT', 'MOODENGUSDT', 'SAFEUSDT', 'SANTOSUSDT', 'TROYUSDT', 'PONKEUSDT', 'COWUSDT', 'CETUSUSDT', '1000000MOGUSDT', 'GRASSUSDT', 'DRIFTUSDT', 'SWELLUSDT', 'ACTUSDT', 'PNUTUSDT', 'HIPPOUSDT', '1000XUSDT', 'DEGENUSDT', 'BANUSDT', 'AKTUSDT', 'SLERFUSDT', 'SCRTUSDT', '1000CHEEMSUSDT', '1000WHYUSDT', 'THEUSDT', 'MORPHOUSDT',  ...

# %%
all_funding_data = []
for symbol in symbols:
    print(f"\n正在采集 {symbol} 的全历史资金费率数据...")
    funding_data = get_full_funding_rate_history(symbol, verify=certifi.where())
    print(f"【{symbol}】获取到 {len(funding_data)} 条记录")
    
    # 为每条记录增加币对标识
    for record in funding_data:
        record["symbol"] = symbol
    all_funding_data.extend(funding_data)
    
    # 为避免请求过快，每个币对之间暂停 0.5 秒
    time.sleep(0.5)
# Out:
# 正在采集 BTCUSDT 的全历史资金费率数据...
# 【BTCUSDT】获取到 5290 条记录
#
# 正在采集 ETHUSDT 的全历史资金费率数据...
# 【ETHUSDT】获取到 5290 条记录
#
# 正在采集 BCHUSDT 的全历史资金费率数据...
# 【BCHUSDT】获取到 5290 条记录
#
# 正在采集 XRPUSDT 的全历史资金费率数据...
# 【XRPUSDT】获取到 5290 条记录
#
# 正在采集 EOSUSDT 的全历史资金费率数据...
# 【EOSUSDT】获取到 5290 条记录
#
# 正在采集 LTCUSDT 的全历史资金费率数据...
# 【LTCUSDT】获取到 5290 条记录
#
# 正在采集 TRXUSDT 的全历史资金费率数据...
# 【TRXUSDT】获取到 5290 条记录
#
# 正在采集 ETCUSDT 的全历史资金费率数据...
# 【ETCUSDT】获取到 5290 条记录
#
# 正在采集 LINKUSDT 的全历史资金费率数据...
# 【LINKUSDT】获取到 5290 条记录
#
# 正在采集 XLMUSDT 的全历史资金费率数据...
# 【XLMUSDT】获取到 5290 条记录
#
# 正在采集 ADAUSDT 的全历史资金费率数据...
# 【ADAUSDT】获取到 5290 条记录
#
# 正在采集 XMRUSDT 的全历史资金费率数据...
# 【XMRUSDT】获取到 5290 条记录
#
# 正在采集 DASHUSDT 的全历史资金费率数据...
# [第 1 次失败] 请求错误：HTTPSConnectionPool(host='fapi.binance.com', port=443): Max retries exceeded with url: /fapi/v1/fundingRate?symbol=DASHUSDT&limit=1000&startTime=1730880000001 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))，等待 2 秒后重试...
# 【DASHUSDT】获取到 5290 条记录
#
# 正在采集 ZECUSDT 的全历史资金费率数据...
# 【ZECUSDT】获取到 5290 条记录
#
# 正在采集 XTZUSDT 的全历史资金费率数据...
# 【XTZUSDT】获取到 5290 条记录
#
# 正在采集 BNBUSDT 的全历史资金费率数据...
# 【BNBUSDT】获取到 5290 条记录
#
# 正在采集 ATOMUSDT 的全历史资金费率数据...
# 【ATOMUSDT】获取到 5290 条记录
#
# 正在采集 ONTUSDT 的全历史资金费率数据...
# 【ONTUSDT】获取到 5290 条记录
#
# 正在采集 IOTAUSDT 的全历史资金费率数据...
# 【IOTAUSDT】获取到 5290 条记录
#
# 正在采集 BATUSDT 的全历史资金费率数据...
# 【BATUSDT】获取到 5290 条记录
#
# 正在采集 VETUSDT 的全历史资金费率数据...
# 【VETUSDT】获取到 5290 条记录
#
# 正在采集 NEOUSDT 的全历史资金费率数据...
# 【NEOUSDT】获取到 5290 条记录
#
# 正在采集 QTUMUSDT 的全历史资金费率数据...
# 【QTUMUSDT】获取到 5290 条记录
#
# 正在采集 IOSTUSDT 的全历史资金费率数据...
# 【IOSTUSDT】获取到 5290 条记录
#
# 正在采集 THETAUSDT 的全历史资金费率数据...
# 【THETAUSDT】获取到 5165 条记录
#
# 正在采集 ALGOUSDT 的全历史资金费率数据...
# [第 1 次失败] 请求错误：HTTPSConnectionPool(host='fapi.binance.com', port=443): Max retries exceeded with url: /fapi/v1/fundingRate?symbol=ALGOUSDT&limit=1000&startTime=1586908800000 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))，等待 2 秒后重试...
# 【ALGOUSDT】获取到 5165 条记录
#
# 正在采集 ZILUSDT 的全历史资金费率数据...
# 【ZILUSDT】获取到 5100 条记录
#
# 正在采集 KNCUSDT 的全历史资金费率数据...
# 【KNCUSDT】获取到 5085 条记录
#
# 正在采集 ZRXUSDT 的全历史资金费率数据...
# 【ZRXUSDT】获取到 5079 条记录
#
# 正在采集 COMPUSDT 的全历史资金费率数据...
# 【COMPUSDT】获取到 5061 条记录
#
# 正在采集 DOGEUSDT 的全历史资金费率数据...
# 【DOGEUSDT】获取到 5031 条记录
#
# 正在采集 SXPUSDT 的全历史资金费率数据...
# 【SXPUSDT】获取到 4998 条记录
#
# 正在采集 KAVAUSDT 的全历史资金费率数据...
# 【KAVAUSDT】获取到 4977 条记录
#
# 正在采集 BANDUSDT 的全历史资金费率数据...
# [第 1 次失败] 请求错误：HTTPSConnectionPool(host='fapi.binance.com', port=443): Max retries exceeded with url: /fapi/v1/fundingRate?symbol=BANDUSDT&limit=1000&startTime=1586908800000 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))，等待 2 秒后重试...
# 【BANDUSDT】获取到 4974 条记录
#
# 正在采集 RLCUSDT 的全历史资金费率数据...
# 【RLCUSDT】获取到 4968 条记录
#
# 正在采集 MKRUSDT 的全历史资金费率数据...
# 【MKRUSDT】获取到 4929 条记录
#
# 正在采集 SNXUSDT 的全历史资金费率数据...
# 【SNXUSDT】获取到 4926 条记录
#
# 正在采集 DOTUSDT 的全历史资金费率数据...
# 【DOTUSDT】获取到 4908 条记录
#
# 正在采集 DEFIUSDT 的全历史资金费率数据...
# 【DEFIUSDT】获取到 4887 条记录
#
# 正在采集 YFIUSDT 的全历史资金费率数据...
# 【YFIUSDT】获取到 4875 条记录
#
# 正在采集 BALUSDT 的全历史资金费率数据...
# 【BALUSDT】获取到 4872 条记录
#
# 正在采集 CRVUSDT 的全历史资金费率数据...
# 【CRVUSDT】获取到 4872 条记录
#
# 正在采集 TRBUSDT 的全历史资金费率数据...
# 【TRBUSDT】获取到 6330 条记录
#
# 正在采集 RUNEUSDT 的全历史资金费率数据...
# 【RUNEUSDT】获取到 4863 条记录
#
# 正在采集 SUSHIUSDT 的全历史资金费率数据...
# 【SUSHIUSDT】获取到 4863 条记录
#
# 正在采集 EGLDUSDT 的全历史资金费率数据...
# 【EGLDUSDT】获取到 4835 条记录
#
# 正在采集 SOLUSDT 的全历史资金费率数据...
# 【SOLUSDT】获取到 4910 条记录
#
# 正在采集 ICXUSDT 的全历史资金费率数据...
# 【ICXUSDT】获取到 4832 条记录
#
# 正在采集 STORJUSDT 的全历史资金费率数据...
# 【STORJUSDT】获取到 4829 条记录
#
# 正在采集 UNIUSDT 的全历史资金费率数据...
# 【UNIUSDT】获取到 4824 条记录
#
# 正在采集 AVAXUSDT 的全历史资金费率数据...
# 【AVAXUSDT】获取到 4808 条记录
#
# 正在采集 ENJUSDT 的全历史资金费率数据...
# 【ENJUSDT】获取到 4788 条记录
#
# 正在采集 FLMUSDT 的全历史资金费率数据...
# 【FLMUSDT】获取到 6278 条记录
#
# 正在采集 KSMUSDT 的全历史资金费率数据...
# 【KSMUSDT】获取到 4743 条记录
#
# 正在采集 NEARUSDT 的全历史资金费率数据...
# 【NEARUSDT】获取到 4742 条记录
#
# 正在采集 AAVEUSDT 的全历史资金费率数据...
# 【AAVEUSDT】获取到 4737 条记录
#
# 正在采集 FILUSDT 的全历史资金费率数据...
# 【FILUSDT】获取到 4737 条记录
#
# 正在采集 RSRUSDT 的全历史资金费率数据...
# 【RSRUSDT】获取到 4728 条记录
#
# 正在采集 LRCUSDT 的全历史资金费率数据...
# 【LRCUSDT】获取到 4728 条记录
#
# 正在采集 BELUSDT 的全历史资金费率数据...
# 【BELUSDT】获取到 4638 条记录
#
# 正在采集 AXSUSDT 的全历史资金费率数据...
# 【AXSUSDT】获取到 4632 条记录
#
# 正在采集 ALPHAUSDT 的全历史资金费率数据...
# 【ALPHAUSDT】获取到 4623 条记录
#
# 正在采集 ZENUSDT 的全历史资金费率数据...
# 【ZENUSDT】获取到 4620 条记录
#
# 正在采集 SKLUSDT 的全历史资金费率数据...
# 【SKLUSDT】获取到 4578 条记录
#
# 正在采集 GRTUSDT 的全历史资金费率数据...
# 【GRTUSDT】获取到 4545 条记录
#
# 正在采集 1INCHUSDT 的全历史资金费率数据...
# 【1INCHUSDT】获取到 4526 条记录
#
# 正在采集 CHZUSDT 的全历史资金费率数据...
# [第 1 次失败] 请求错误：HTTPSConnectionPool(host='fapi.binance.com', port=443): Max retries exceeded with url: /fapi/v1/fundingRate?symbol=CHZUSDT&limit=1000&startTime=1586908800000 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))，等待 2 秒后重试...
# 【CHZUSDT】获取到 4518 条记录
#
# 正在采集 SANDUSDT 的全历史资金费率数据...
# 【SANDUSDT】获取到 4434 条记录
#
# 正在采集 ANKRUSDT 的全历史资金费率数据...
# 【ANKRUSDT】获取到 4433 条记录
#
# 正在采集 RVNUSDT 的全历史资金费率数据...
# 【RVNUSDT】获取到 4347 条记录
#
# 正在采集 SFPUSDT 的全历史资金费率数据...
# 【SFPUSDT】获取到 4344 条记录
#
# 正在采集 COTIUSDT 的全历史资金费率数据...
# 【COTIUSDT】获取到 4302 条记录
#
# 正在采集 CHRUSDT 的全历史资金费率数据...
# 【CHRUSDT】获取到 4296 条记录
#
# 正在采集 MANAUSDT 的全历史资金费率数据...
# 【MANAUSDT】获取到 4287 条记录
#
# 正在采集 ALICEUSDT 的全历史资金费率数据...
# 【ALICEUSDT】获取到 4286 条记录
#
# 正在采集 HBARUSDT 的全历史资金费率数据...
# 【HBARUSDT】获取到 4281 条记录
#
# 正在采集 ONEUSDT 的全历史资金费率数据...
# 【ONEUSDT】获取到 4278 条记录
#
# 正在采集 LINAUSDT 的全历史资金费率数据...
# 【LINAUSDT】获取到 4275 条记录
#
# 正在采集 STMXUSDT 的全历史资金费率数据...
# 【STMXUSDT】获取到 5750 条记录
#
# 正在采集 DENTUSDT 的全历史资金费率数据...
# 【DENTUSDT】获取到 4260 条记录
#
# 正在采集 CELRUSDT 的全历史资金费率数据...
# 【CELRUSDT】获取到 4245 条记录
#
# 正在采集 HOTUSDT 的全历史资金费率数据...
# 【HOTUSDT】获取到 4242 条记录
#
# 正在采集 MTLUSDT 的全历史资金费率数据...
# 【MTLUSDT】获取到 4244 条记录
#
# 正在采集 OGNUSDT 的全历史资金费率数据...
# 【OGNUSDT】获取到 4236 条记录
#
# 正在采集 NKNUSDT 的全历史资金费率数据...
# 【NKNUSDT】获取到 4212 条记录
#
# 正在采集 1000SHIBUSDT 的全历史资金费率数据...
# 【1000SHIBUSDT】获取到 4118 条记录
#
# 正在采集 BAKEUSDT 的全历史资金费率数据...
# 【BAKEUSDT】获取到 4092 条记录
#
# 正在采集 GTCUSDT 的全历史资金费率数据...
# 【GTCUSDT】获取到 4023 条记录
#
# 正在采集 BTCDOMUSDT 的全历史资金费率数据...
# [第 1 次失败] 请求错误：HTTPSConnectionPool(host='fapi.binance.com', port=443): Max retries exceeded with url: /fapi/v1/fundingRate?symbol=BTCDOMUSDT&limit=1000&startTime=1653033600004 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))，等待 2 秒后重试...
# 【BTCDOMUSDT】获取到 3993 条记录
#
# 正在采集 IOTXUSDT 的全历史资金费率数据...
# 【IOTXUSDT】获取到 3839 条记录
#
# 正在采集 C98USDT 的全历史资金费率数据...
# 【C98USDT】获取到 3801 条记录
#
# 正在采集 MASKUSDT 的全历史资金费率数据...
# 【MASKUSDT】获取到 3795 条记录
#
# 正在采集 ATAUSDT 的全历史资金费率数据...
# 【ATAUSDT】获取到 3783 条记录
#
# 正在采集 DYDXUSDT 的全历史资金费率数据...
# 【DYDXUSDT】获取到 3752 条记录
#
# 正在采集 1000XECUSDT 的全历史资金费率数据...
# 【1000XECUSDT】获取到 3729 条记录
#
# 正在采集 GALAUSDT 的全历史资金费率数据...
# 【GALAUSDT】获取到 3728 条记录
#
# 正在采集 CELOUSDT 的全历史资金费率数据...
# 【CELOUSDT】获取到 3699 条记录
#
# 正在采集 ARUSDT 的全历史资金费率数据...
# 【ARUSDT】获取到 3699 条记录
#
# 正在采集 ARPAUSDT 的全历史资金费率数据...
# 【ARPAUSDT】获取到 3633 条记录
#
# 正在采集 CTSIUSDT 的全历史资金费率数据...
# 【CTSIUSDT】获取到 3612 条记录
#
# 正在采集 LPTUSDT 的全历史资金费率数据...
# 【LPTUSDT】获取到 5052 条记录
#
# 正在采集 ENSUSDT 的全历史资金费率数据...
# 【ENSUSDT】获取到 3509 条记录
#
# 正在采集 PEOPLEUSDT 的全历史资金费率数据...
# 【PEOPLEUSDT】获取到 3437 条记录
#
# 正在采集 ROSEUSDT 的全历史资金费率数据...
# 【ROSEUSDT】获取到 3417 条记录
#
# 正在采集 DUSKUSDT 的全历史资金费率数据...
# 【DUSKUSDT】获取到 3395 条记录
#
# 正在采集 FLOWUSDT 的全历史资金费率数据...
# 【FLOWUSDT】获取到 3293 条记录
#
# 正在采集 IMXUSDT 的全历史资金费率数据...
# 【IMXUSDT】获取到 4752 条记录
#
# 正在采集 API3USDT 的全历史资金费率数据...
# 【API3USDT】获取到 4721 条记录
#
# 正在采集 GMTUSDT 的全历史资金费率数据...
# 【GMTUSDT】获取到 3194 条记录
#
# 正在采集 APEUSDT 的全历史资金费率数据...
# 【APEUSDT】获取到 3185 条记录
#
# 正在采集 WOOUSDT 的全历史资金费率数据...
# 【WOOUSDT】获取到 3122 条记录
#
# 正在采集 JASMYUSDT 的全历史资金费率数据...
# 【JASMYUSDT】获取到 3087 条记录
#
# 正在采集 OPUSDT 的全历史资金费率数据...
# 【OPUSDT】获取到 2958 条记录
#
# 正在采集 INJUSDT 的全历史资金费率数据...
# 【INJUSDT】获取到 2729 条记录
#
# 正在采集 STGUSDT 的全历史资金费率数据...
# 【STGUSDT】获取到 2702 条记录
#
# 正在采集 SPELLUSDT 的全历史资金费率数据...
# 【SPELLUSDT】获取到 2666 条记录
#
# 正在采集 1000LUNCUSDT 的全历史资金费率数据...
# 【1000LUNCUSDT】获取到 2657 条记录
#
# 正在采集 LUNA2USDT 的全历史资金费率数据...
# 【LUNA2USDT】获取到 2656 条记录
#
# 正在采集 LDOUSDT 的全历史资金费率数据...
# 【LDOUSDT】获取到 2619 条记录
#
# 正在采集 ICPUSDT 的全历史资金费率数据...
# 【ICPUSDT】获取到 4116 条记录
#
# 正在采集 APTUSDT 的全历史资金费率数据...
# 【APTUSDT】获取到 2540 条记录
#
# 正在采集 QNTUSDT 的全历史资金费率数据...
# 【QNTUSDT】获取到 2535 条记录
#
# 正在采集 FETUSDT 的全历史资金费率数据...
# 【FETUSDT】获取到 2271 条记录
#
# 正在采集 FXSUSDT 的全历史资金费率数据...
# 【FXSUSDT】获取到 2259 条记录
#
# 正在采集 HOOKUSDT 的全历史资金费率数据...
# 【HOOKUSDT】获取到 2259 条记录
#
# 正在采集 MAGICUSDT 的全历史资金费率数据...
# 【MAGICUSDT】获取到 2249 条记录
#
# 正在采集 TUSDT 的全历史资金费率数据...
# 【TUSDT】获取到 2225 条记录
#
# 正在采集 HIGHUSDT 的全历史资金费率数据...
# 【HIGHUSDT】获取到 2217 条记录
#
# 正在采集 MINAUSDT 的全历史资金费率数据...
# 【MINAUSDT】获取到 2217 条记录
#
# 正在采集 ASTRUSDT 的全历史资金费率数据...
# 【ASTRUSDT】获取到 2187 条记录
#
# 正在采集 PHBUSDT 的全历史资金费率数据...
# 【PHBUSDT】获取到 2180 条记录
#
# 正在采集 GMXUSDT 的全历史资金费率数据...
# 【GMXUSDT】获取到 2175 条记录
#
# 正在采集 CFXUSDT 的全历史资金费率数据...
# 【CFXUSDT】获取到 2166 条记录
#
# 正在采集 STXUSDT 的全历史资金费率数据...
# 【STXUSDT】获取到 2163 条记录
#
# 正在采集 BNXUSDT 的全历史资金费率数据...
# 【BNXUSDT】获取到 3235 条记录
#
# 正在采集 ACHUSDT 的全历史资金费率数据...
# 【ACHUSDT】获取到 2160 条记录
#
# 正在采集 SSVUSDT 的全历史资金费率数据...
# 【SSVUSDT】获取到 2157 条记录
#
# 正在采集 CKBUSDT 的全历史资金费率数据...
# 【CKBUSDT】获取到 2142 条记录
#
# 正在采集 PERPUSDT 的全历史资金费率数据...
# 【PERPUSDT】获取到 3596 条记录
#
# 正在采集 TRUUSDT 的全历史资金费率数据...
# 【TRUUSDT】获取到 2123 条记录
#
# 正在采集 LQTYUSDT 的全历史资金费率数据...
# 【LQTYUSDT】获取到 2114 条记录
#
# 正在采集 USDCUSDT 的全历史资金费率数据...
# 【USDCUSDT】获取到 2104 条记录
#
# 正在采集 IDUSDT 的全历史资金费率数据...
# 【IDUSDT】获取到 2073 条记录
#
# 正在采集 ARBUSDT 的全历史资金费率数据...
# 【ARBUSDT】获取到 2073 条记录
#
# 正在采集 JOEUSDT 的全历史资金费率数据...
# 【JOEUSDT】获取到 2057 条记录
#
# 正在采集 TLMUSDT 的全历史资金费率数据...
# 【TLMUSDT】获取到 3918 条记录
#
# 正在采集 AMBUSDT 的全历史资金费率数据...
# 【AMBUSDT】获取到 3516 条记录
#
# 正在采集 LEVERUSDT 的全历史资金费率数据...
# 【LEVERUSDT】获取到 2052 条记录
#
# 正在采集 RDNTUSDT 的全历史资金费率数据...
# 【RDNTUSDT】获取到 2036 条记录
#
# 正在采集 HFTUSDT 的全历史资金费率数据...
# 【HFTUSDT】获取到 2033 条记录
#
# 正在采集 XVSUSDT 的全历史资金费率数据...
# 【XVSUSDT】获取到 2013 条记录
#
# 正在采集 ETHBTC 的全历史资金费率数据...
# 【ETHBTC】获取到 1976 条记录
#
# 正在采集 BLURUSDT 的全历史资金费率数据...
# 【BLURUSDT】获取到 1967 条记录
#
# 正在采集 EDUUSDT 的全历史资金费率数据...
# 【EDUUSDT】获取到 1964 条记录
#
# 正在采集 SUIUSDT 的全历史资金费率数据...
# 【SUIUSDT】获取到 1949 条记录
#
# 正在采集 1000PEPEUSDT 的全历史资金费率数据...
# 【1000PEPEUSDT】获取到 1943 条记录
#
# 正在采集 1000FLOKIUSDT 的全历史资金费率数据...
# 【1000FLOKIUSDT】获取到 1940 条记录
#
# 正在采集 UMAUSDT 的全历史资金费率数据...
# 【UMAUSDT】获取到 3097 条记录
#
# 正在采集 COMBOUSDT 的全历史资金费率数据...
# 【COMBOUSDT】获取到 1860 条记录
#
# 正在采集 NMRUSDT 的全历史资金费率数据...
# 【NMRUSDT】获取到 3291 条记录
#
# 正在采集 MAVUSDT 的全历史资金费率数据...
# 【MAVUSDT】获取到 1781 条记录
#
# 正在采集 XVGUSDT 的全历史资金费率数据...
# 【XVGUSDT】获取到 1777 条记录
#
# 正在采集 WLDUSDT 的全历史资金费率数据...
# 【WLDUSDT】获取到 1703 条记录
#
# 正在采集 PENDLEUSDT 的全历史资金费率数据...
# 【PENDLEUSDT】获取到 1700 条记录
#
# 正在采集 ARKMUSDT 的全历史资金费率数据...
# 【ARKMUSDT】获取到 1694 条记录
#
# 正在采集 AGLDUSDT 的全历史资金费率数据...
# 【AGLDUSDT】获取到 1691 条记录
#
# 正在采集 YGGUSDT 的全历史资金费率数据...
# 【YGGUSDT】获取到 3143 条记录
#
# 正在采集 DODOXUSDT 的全历史资金费率数据...
# 【DODOXUSDT】获取到 3125 条记录
#
# 正在采集 BNTUSDT 的全历史资金费率数据...
# 【BNTUSDT】获取到 2017 条记录
#
# 正在采集 OXTUSDT 的全历史资金费率数据...
# 【OXTUSDT】获取到 1652 条记录
#
# 正在采集 SEIUSDT 的全历史资金费率数据...
# 【SEIUSDT】获取到 1634 条记录
#
# 正在采集 CYBERUSDT 的全历史资金费率数据...
# 【CYBERUSDT】获取到 3122 条记录
#
# 正在采集 HIFIUSDT 的全历史资金费率数据...
# 【HIFIUSDT】获取到 3009 条记录
#
# 正在采集 ARKUSDT 的全历史资金费率数据...
# 【ARKUSDT】获取到 1532 条记录
#
# 正在采集 BICOUSDT 的全历史资金费率数据...
# 【BICOUSDT】获取到 1506 条记录
#
# 正在采集 BIGTIMEUSDT 的全历史资金费率数据...
# 【BIGTIMEUSDT】获取到 2926 条记录
#
# 正在采集 WAXPUSDT 的全历史资金费率数据...
# 【WAXPUSDT】获取到 2891 条记录
#
# 正在采集 BSVUSDT 的全历史资金费率数据...
# 【BSVUSDT】获取到 2879 条记录
#
# 正在采集 RIFUSDT 的全历史资金费率数据...
# 【RIFUSDT】获取到 2918 条记录
#
# 正在采集 POLYXUSDT 的全历史资金费率数据...
# 【POLYXUSDT】获取到 2853 条记录
#
# 正在采集 GASUSDT 的全历史资金费率数据...
# 【GASUSDT】获取到 2853 条记录
#
# 正在采集 POWRUSDT 的全历史资金费率数据...
# 【POWRUSDT】获取到 2841 条记录
#
# 正在采集 TIAUSDT 的全历史资金费率数据...
# 【TIAUSDT】获取到 2811 条记录
#
# 正在采集 CAKEUSDT 的全历史资金费率数据...
# 【CAKEUSDT】获取到 2800 条记录
#
# 正在采集 MEMEUSDT 的全历史资金费率数据...
# 【MEMEUSDT】获取到 2794 条记录
#
# 正在采集 TWTUSDT 的全历史资金费率数据...
# 【TWTUSDT】获取到 2795 条记录
#
# 正在采集 TOKENUSDT 的全历史资金费率数据...
# 【TOKENUSDT】获取到 2794 条记录
#
# 正在采集 ORDIUSDT 的全历史资金费率数据...
# 【ORDIUSDT】获取到 2770 条记录
#
# 正在采集 STEEMUSDT 的全历史资金费率数据...
# 【STEEMUSDT】获取到 2764 条记录
#
# 正在采集 BADGERUSDT 的全历史资金费率数据...
# 【BADGERUSDT】获取到 2759 条记录
#
# 正在采集 ILVUSDT 的全历史资金费率数据...
# [第 1 次失败] 请求错误：HTTPSConnectionPool(host='fapi.binance.com', port=443): Max retries exceeded with url: /fapi/v1/fundingRate?symbol=ILVUSDT&limit=1000&startTime=1728417600001 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))，等待 2 秒后重试...
# 【ILVUSDT】获取到 2752 条记录
#
# 正在采集 NTRNUSDT 的全历史资金费率数据...
# 【NTRNUSDT】获取到 2729 条记录
#
# 正在采集 KASUSDT 的全历史资金费率数据...
# 【KASUSDT】获取到 2715 条记录
#
# 正在采集 BEAMXUSDT 的全历史资金费率数据...
# 【BEAMXUSDT】获取到 2711 条记录
#
# 正在采集 1000BONKUSDT 的全历史资金费率数据...
# 【1000BONKUSDT】获取到 2680 条记录
#
# 正在采集 PYTHUSDT 的全历史资金费率数据...
# 【PYTHUSDT】获取到 2680 条记录
#
# 正在采集 SUPERUSDT 的全历史资金费率数据...
# 【SUPERUSDT】获取到 2656 条记录
#
# 正在采集 USTCUSDT 的全历史资金费率数据...
# 【USTCUSDT】获取到 2651 条记录
#
# 正在采集 ONGUSDT 的全历史资金费率数据...
# 【ONGUSDT】获取到 2650 条记录
#
# 正在采集 ETHWUSDT 的全历史资金费率数据...
# 【ETHWUSDT】获取到 2644 条记录
#
# 正在采集 JTOUSDT 的全历史资金费率数据...
# 【JTOUSDT】获取到 2585 条记录
#
# 正在采集 1000SATSUSDT 的全历史资金费率数据...
# 【1000SATSUSDT】获取到 2560 条记录
#
# 正在采集 AUCTIONUSDT 的全历史资金费率数据...
# 【AUCTIONUSDT】获取到 2542 条记录
#
# 正在采集 1000RATSUSDT 的全历史资金费率数据...
# 【1000RATSUSDT】获取到 2542 条记录
#
# 正在采集 ACEUSDT 的全历史资金费率数据...
# 【ACEUSDT】获取到 2525 条记录
#
# 正在采集 MOVRUSDT 的全历史资金费率数据...
# 【MOVRUSDT】获取到 2476 条记录
#
# 正在采集 NFPUSDT 的全历史资金费率数据...
# 【NFPUSDT】获取到 2470 条记录
#
# 正在采集 BTCUSDC 的全历史资金费率数据...
# 【BTCUSDC】获取到 1217 条记录
#
# 正在采集 ETHUSDC 的全历史资金费率数据...
# 【ETHUSDC】获取到 1217 条记录
#
# 正在采集 BNBUSDC 的全历史资金费率数据...
# 【BNBUSDC】获取到 1217 条记录
#
# 正在采集 SOLUSDC 的全历史资金费率数据...
# 【SOLUSDC】获取到 1217 条记录
#
# 正在采集 XRPUSDC 的全历史资金费率数据...
# 【XRPUSDC】获取到 1217 条记录
#
# 正在采集 AIUSDT 的全历史资金费率数据...
# 【AIUSDT】获取到 2398 条记录
#
# 正在采集 XAIUSDT 的全历史资金费率数据...
# 【XAIUSDT】获取到 2392 条记录
#
# 正在采集 DOGEUSDC 的全历史资金费率数据...
# 【DOGEUSDC】获取到 1172 条记录
#
# 正在采集 WIFUSDT 的全历史资金费率数据...
# 【WIFUSDT】获取到 2338 条记录
#
# 正在采集 MANTAUSDT 的全历史资金费率数据...
# 【MANTAUSDT】获取到 2338 条记录
#
# 正在采集 ONDOUSDT 的全历史资金费率数据...
# 【ONDOUSDT】获取到 2326 条记录
#
# 正在采集 LSKUSDT 的全历史资金费率数据...
# 【LSKUSDT】获取到 2296 条记录
#
# 正在采集 ALTUSDT 的全历史资金费率数据...
# 【ALTUSDT】获取到 2296 条记录
#
# 正在采集 JUPUSDT 的全历史资金费率数据...
# 【JUPUSDT】获取到 2257 条记录
#
# 正在采集 ZETAUSDT 的全历史资金费率数据...
# 【ZETAUSDT】获取到 2250 条记录
#
# 正在采集 RONINUSDT 的全历史资金费率数据...
# 【RONINUSDT】获取到 2228 条记录
#
# 正在采集 DYMUSDT 的全历史资金费率数据...
# 【DYMUSDT】获取到 2220 条记录
#
# 正在采集 SUIUSDC 的全历史资金费率数据...
# 【SUIUSDC】获取到 1110 条记录
#
# 正在采集 OMUSDT 的全历史资金费率数据...
# 【OMUSDT】获取到 2183 条记录
#
# 正在采集 LINKUSDC 的全历史资金费率数据...
# 【LINKUSDC】获取到 1087 条记录
#
# 正在采集 PIXELUSDT 的全历史资金费率数据...
# 【PIXELUSDT】获取到 2146 条记录
#
# 正在采集 STRKUSDT 的全历史资金费率数据...
# 【STRKUSDT】获取到 2140 条记录
#
# 正在采集 ORDIUSDC 的全历史资金费率数据...
# 【ORDIUSDC】获取到 2138 条记录
#
# 正在采集 GLMUSDT 的全历史资金费率数据...
# 【GLMUSDT】获取到 2130 条记录
#
# 正在采集 PORTALUSDT 的全历史资金费率数据...
# [第 1 次失败] 请求错误：HTTPSConnectionPool(host='fapi.binance.com', port=443): Max retries exceeded with url: /fapi/v1/fundingRate?symbol=PORTALUSDT&limit=1000&startTime=1723608000001 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))，等待 2 秒后重试...
# 【PORTALUSDT】获取到 2086 条记录
#
# 正在采集 TONUSDT 的全历史资金费率数据...
# 【TONUSDT】获取到 2081 条记录
#
# 正在采集 AXLUSDT 的全历史资金费率数据...
# 【AXLUSDT】获取到 2080 条记录
#
# 正在采集 MYROUSDT 的全历史资金费率数据...
# 【MYROUSDT】获取到 2058 条记录
#
# 正在采集 1000PEPEUSDC 的全历史资金费率数据...
# 【1000PEPEUSDC】获取到 1029 条记录
#
# 正在采集 METISUSDT 的全历史资金费率数据...
# 【METISUSDT】获取到 2018 条记录
#
# 正在采集 AEVOUSDT 的全历史资金费率数据...
# 【AEVOUSDT】获取到 2008 条记录
#
# 正在采集 WLDUSDC 的全历史资金费率数据...
# 【WLDUSDC】获取到 1004 条记录
#
# 正在采集 VANRYUSDT 的全历史资金费率数据...
# 【VANRYUSDT】获取到 2008 条记录
#
# 正在采集 BOMEUSDT 的全历史资金费率数据...
# 【BOMEUSDT】获取到 1992 条记录
#
# 正在采集 ETHFIUSDT 的全历史资金费率数据...
# 【ETHFIUSDT】获取到 1978 条记录
#
# 正在采集 AVAXUSDC 的全历史资金费率数据...
# 【AVAXUSDC】获取到 989 条记录
#
# 正在采集 1000SHIBUSDC 的全历史资金费率数据...
# 【1000SHIBUSDC】获取到 965 条记录
#
# 正在采集 ENAUSDT 的全历史资金费率数据...
# 【ENAUSDT】获取到 1888 条记录
#
# 正在采集 WUSDT 的全历史资金费率数据...
# 【WUSDT】获取到 1882 条记录
#
# 正在采集 WIFUSDC 的全历史资金费率数据...
# 【WIFUSDC】获取到 1883 条记录
#
# 正在采集 BCHUSDC 的全历史资金费率数据...
# 【BCHUSDC】获取到 944 条记录
#
# 正在采集 TNSRUSDT 的全历史资金费率数据...
# 【TNSRUSDT】获取到 1851 条记录
#
# 正在采集 SAGAUSDT 的全历史资金费率数据...
# 【SAGAUSDT】获取到 1849 条记录
#
# 正在采集 LTCUSDC 的全历史资金费率数据...
# 【LTCUSDC】获取到 920 条记录
#
# 正在采集 NEARUSDC 的全历史资金费率数据...
# 【NEARUSDC】获取到 920 条记录
#
# 正在采集 TAOUSDT 的全历史资金费率数据...
# 【TAOUSDT】获取到 1834 条记录
#
# 正在采集 OMNIUSDT 的全历史资金费率数据...
# 【OMNIUSDT】获取到 1798 条记录
#
# 正在采集 ARBUSDC 的全历史资金费率数据...
# 【ARBUSDC】获取到 902 条记录
#
# 正在采集 NEOUSDC 的全历史资金费率数据...
# 【NEOUSDC】获取到 902 条记录
#
# 正在采集 FILUSDC 的全历史资金费率数据...
# 【FILUSDC】获取到 902 条记录
#
# 正在采集 TIAUSDC 的全历史资金费率数据...
# 【TIAUSDC】获取到 1754 条记录
#
# 正在采集 BOMEUSDC 的全历史资金费率数据...
# 【BOMEUSDC】获取到 1754 条记录
#
# 正在采集 REZUSDT 的全历史资金费率数据...
# 【REZUSDT】获取到 1720 条记录
#
# 正在采集 ENAUSDC 的全历史资金费率数据...
# 【ENAUSDC】获取到 1714 条记录
#
# 正在采集 ETHFIUSDC 的全历史资金费率数据...
# 【ETHFIUSDC】获取到 1714 条记录
#
# 正在采集 1000BONKUSDC 的全历史资金费率数据...
# 【1000BONKUSDC】获取到 1714 条记录
#
# 正在采集 BBUSDT 的全历史资金费率数据...
# 【BBUSDT】获取到 1642 条记录
#
# 正在采集 NOTUSDT 的全历史资金费率数据...
# 【NOTUSDT】获取到 1624 条记录
#
# 正在采集 TURBOUSDT 的全历史资金费率数据...
# 【TURBOUSDT】获取到 1540 条记录
#
# 正在采集 IOUSDT 的全历史资金费率数据...
# 【IOUSDT】获取到 1468 条记录
#
# 正在采集 ZKUSDT 的全历史资金费率数据...
# 【ZKUSDT】获取到 1433 条记录
#
# 正在采集 MEWUSDT 的全历史资金费率数据...
# 【MEWUSDT】获取到 1432 条记录
#
# 正在采集 LISTAUSDT 的全历史资金费率数据...
# 【LISTAUSDT】获取到 1414 条记录
#
# 正在采集 ZROUSDT 的全历史资金费率数据...
# 【ZROUSDT】获取到 1414 条记录
#
# 正在采集 CRVUSDC 的全历史资金费率数据...
# 【CRVUSDC】获取到 674 条记录
#
# 正在采集 RENDERUSDT 的全历史资金费率数据...
# 【RENDERUSDT】获取到 1199 条记录
#
# 正在采集 BANANAUSDT 的全历史资金费率数据...
# 【BANANAUSDT】获取到 1083 条记录
#
# 正在采集 RAREUSDT 的全历史资金费率数据...
# 【RAREUSDT】获取到 1078 条记录
#
# 正在采集 GUSDT 的全历史资金费率数据...
# 【GUSDT】获取到 1078 条记录
#
# 正在采集 SYNUSDT 的全历史资金费率数据...
# 【SYNUSDT】获取到 1072 条记录
#
# 正在采集 SYSUSDT 的全历史资金费率数据...
# 【SYSUSDT】获取到 1055 条记录
#
# 正在采集 VOXELUSDT 的全历史资金费率数据...
# 【VOXELUSDT】获取到 1049 条记录
#
# 正在采集 BRETTUSDT 的全历史资金费率数据...
# 【BRETTUSDT】获取到 1049 条记录
#
# 正在采集 ALPACAUSDT 的全历史资金费率数据...
# 【ALPACAUSDT】获取到 1037 条记录
#
# 正在采集 POPCATUSDT 的全历史资金费率数据...
# 【POPCATUSDT】获取到 1036 条记录
#
# 正在采集 SUNUSDT 的全历史资金费率数据...
# 【SUNUSDT】获取到 1036 条记录
#
# 正在采集 VIDTUSDT 的全历史资金费率数据...
# 【VIDTUSDT】获取到 1032 条记录
#
# 正在采集 NULSUSDT 的全历史资金费率数据...
# 【NULSUSDT】获取到 1014 条记录
#
# 正在采集 DOGSUSDT 的全历史资金费率数据...
# 【DOGSUSDT】获取到 1012 条记录
#
# 正在采集 MBOXUSDT 的全历史资金费率数据...
# 【MBOXUSDT】获取到 1001 条记录
#
# 正在采集 CHESSUSDT 的全历史资金费率数据...
# 【CHESSUSDT】获取到 996 条记录
#
# 正在采集 FLUXUSDT 的全历史资金费率数据...
# 【FLUXUSDT】获取到 966 条记录
#
# 正在采集 BSWUSDT 的全历史资金费率数据...
# 【BSWUSDT】获取到 954 条记录
#
# 正在采集 QUICKUSDT 的全历史资金费率数据...
# 【QUICKUSDT】获取到 948 条记录
#
# 正在采集 NEIROETHUSDT 的全历史资金费率数据...
# 【NEIROETHUSDT】获取到 946 条记录
#
# 正在采集 RPLUSDT 的全历史资金费率数据...
# 【RPLUSDT】获取到 928 条记录
#
# 正在采集 AERGOUSDT 的全历史资金费率数据...
# 【AERGOUSDT】获取到 922 条记录
#
# 正在采集 POLUSDT 的全历史资金费率数据...
# 【POLUSDT】获取到 904 条记录
#
# 正在采集 UXLINKUSDT 的全历史资金费率数据...
# 【UXLINKUSDT】获取到 892 条记录
#
# 正在采集 1MBABYDOGEUSDT 的全历史资金费率数据...
# 【1MBABYDOGEUSDT】获取到 887 条记录
#
# 正在采集 NEIROUSDT 的全历史资金费率数据...
# 【NEIROUSDT】获取到 887 条记录
#
# 正在采集 KDAUSDT 的全历史资金费率数据...
# 【KDAUSDT】获取到 874 条记录
#
# 正在采集 FIDAUSDT 的全历史资金费率数据...
# 【FIDAUSDT】获取到 868 条记录
#
# 正在采集 FIOUSDT 的全历史资金费率数据...
# 【FIOUSDT】获取到 863 条记录
#
# 正在采集 CATIUSDT 的全历史资金费率数据...
# 【CATIUSDT】获取到 869 条记录
#
# 正在采集 GHSTUSDT 的全历史资金费率数据...
# 【GHSTUSDT】获取到 844 条记录
#
# 正在采集 LOKAUSDT 的全历史资金费率数据...
# 【LOKAUSDT】获取到 839 条记录
#
# 正在采集 HMSTRUSDT 的全历史资金费率数据...
# 【HMSTRUSDT】获取到 826 条记录
#
# 正在采集 REIUSDT 的全历史资金费率数据...
# 【REIUSDT】获取到 821 条记录
#
# 正在采集 COSUSDT 的全历史资金费率数据...
# 【COSUSDT】获取到 802 条记录
#
# 正在采集 EIGENUSDT 的全历史资金费率数据...
# 【EIGENUSDT】获取到 798 条记录
#
# 正在采集 DIAUSDT 的全历史资金费率数据...
# 【DIAUSDT】获取到 790 条记录
#
# 正在采集 1000CATUSDT 的全历史资金费率数据...
# 【1000CATUSDT】获取到 676 条记录
#
# 正在采集 SCRUSDT 的全历史资金费率数据...
# 【SCRUSDT】获取到 671 条记录
#
# 正在采集 GOATUSDT 的全历史资金费率数据...
# 【GOATUSDT】获取到 658 条记录
#
# 正在采集 MOODENGUSDT 的全历史资金费率数据...
# 【MOODENGUSDT】获取到 653 条记录
#
# 正在采集 SAFEUSDT 的全历史资金费率数据...
# 【SAFEUSDT】获取到 652 条记录
#
# 正在采集 SANTOSUSDT 的全历史资金费率数据...
# 【SANTOSUSDT】获取到 634 条记录
#
# 正在采集 TROYUSDT 的全历史资金费率数据...
# 【TROYUSDT】获取到 616 条记录
#
# 正在采集 PONKEUSDT 的全历史资金费率数据...
# 【PONKEUSDT】获取到 592 条记录
#
# 正在采集 COWUSDT 的全历史资金费率数据...
# 【COWUSDT】获取到 580 条记录
#
# 正在采集 CETUSUSDT 的全历史资金费率数据...
# 【CETUSUSDT】获取到 580 条记录
#
# 正在采集 1000000MOGUSDT 的全历史资金费率数据...
# 【1000000MOGUSDT】获取到 574 条记录
#
# 正在采集 GRASSUSDT 的全历史资金费率数据...
# 【GRASSUSDT】获取到 568 条记录
#
# 正在采集 DRIFTUSDT 的全历史资金费率数据...
# 【DRIFTUSDT】获取到 568 条记录
#
# 正在采集 SWELLUSDT 的全历史资金费率数据...
# 【SWELLUSDT】获取到 568 条记录
#
# 正在采集 ACTUSDT 的全历史资金费率数据...
# 【ACTUSDT】获取到 550 条记录
#
# 正在采集 PNUTUSDT 的全历史资金费率数据...
# 【PNUTUSDT】获取到 550 条记录
#
# 正在采集 HIPPOUSDT 的全历史资金费率数据...
# [第 1 次失败] 请求错误：HTTPSConnectionPool(host='fapi.binance.com', port=443): Max retries exceeded with url: /fapi/v1/fundingRate?symbol=HIPPOUSDT&limit=1000&startTime=1586908800000 (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))，等待 2 秒后重试...
# 【HIPPOUSDT】获取到 538 条记录
#
# 正在采集 1000XUSDT 的全历史资金费率数据...
# 【1000XUSDT】获取到 538 条记录
#
# 正在采集 DEGENUSDT 的全历史资金费率数据...
# 【DEGENUSDT】获取到 527 条记录
#
# 正在采集 BANUSDT 的全历史资金费率数据...
# 【BANUSDT】获取到 518 条记录
#
# 正在采集 AKTUSDT 的全历史资金费率数据...
# 【AKTUSDT】获取到 509 条记录
#
# 正在采集 SLERFUSDT 的全历史资金费率数据...
# 【SLERFUSDT】获取到 491 条记录
#
# 正在采集 SCRTUSDT 的全历史资金费率数据...
# 【SCRTUSDT】获取到 491 条记录
#
# 正在采集 1000CHEEMSUSDT 的全历史资金费率数据...
# 【1000CHEEMSUSDT】获取到 467 条记录
#
# 正在采集 1000WHYUSDT 的全历史资金费率数据...
# 【1000WHYUSDT】获取到 467 条记录
#
# 正在采集 THEUSDT 的全历史资金费率数据...
# 【THEUSDT】获取到 454 条记录
#
# 正在采集 MORPHOUSDT 的全历史资金费率数据...
# 【MORPHOUSDT】获取到 454 条记录
#
# 正在采集 CHILLGUYUSDT 的全历史资金费率数据...
# 【CHILLGUYUSDT】获取到 454 条记录
#
# 正在采集 KAIAUSDT 的全历史资金费率数据...
# 【KAIAUSDT】获取到 412 条记录
#
# 正在采集 AEROUSDT 的全历史资金费率数据...
# 【AEROUSDT】获取到 412 条记录
#
# 正在采集 ACXUSDT 的全历史资金费率数据...
# 【ACXUSDT】获取到 400 条记录
#
# 正在采集 ORCAUSDT 的全历史资金费率数据...
# 【ORCAUSDT】获取到 400 条记录
#
# 正在采集 MOVEUSDT 的全历史资金费率数据...
# 【MOVEUSDT】获取到 382 条记录
#
# 正在采集 RAYSOLUSDT 的全历史资金费率数据...
# 【RAYSOLUSDT】获取到 372 条记录
#
# 正在采集 KOMAUSDT 的全历史资金费率数据...
# 【KOMAUSDT】获取到 376 条记录
#
# 正在采集 VIRTUALUSDT 的全历史资金费率数据...
# 【VIRTUALUSDT】获取到 376 条记录
#
# 正在采集 SPXUSDT 的全历史资金费率数据...
# 【SPXUSDT】获取到 376 条记录
#
# 正在采集 MEUSDT 的全历史资金费率数据...
# 【MEUSDT】获取到 376 条记录
#
# 正在采集 AVAUSDT 的全历史资金费率数据...
# 【AVAUSDT】获取到 358 条记录
#
# 正在采集 DEGOUSDT 的全历史资金费率数据...
# 【DEGOUSDT】获取到 358 条记录
#
# 正在采集 VELODROMEUSDT 的全历史资金费率数据...
# 【VELODROMEUSDT】获取到 358 条记录
#
# 正在采集 MOCAUSDT 的全历史资金费率数据...
# 【MOCAUSDT】获取到 341 条记录
#
# 正在采集 VANAUSDT 的全历史资金费率数据...
# 【VANAUSDT】获取到 340 条记录
#
# 正在采集 PENGUUSDT 的全历史资金费率数据...
# 【PENGUUSDT】获取到 334 条记录
#
# 正在采集 LUMIAUSDT 的全历史资金费率数据...
# 【LUMIAUSDT】获取到 329 条记录
#
# 正在采集 USUALUSDT 的全历史资金费率数据...
# 【USUALUSDT】获取到 328 条记录
#
# 正在采集 AIXBTUSDT 的全历史资金费率数据...
# 【AIXBTUSDT】获取到 315 条记录
#
# 正在采集 FARTCOINUSDT 的全历史资金费率数据...
# 【FARTCOINUSDT】获取到 315 条记录
#
# 正在采集 KMNOUSDT 的全历史资金费率数据...
# 【KMNOUSDT】获取到 315 条记录
#
# 正在采集 CGPTUSDT 的全历史资金费率数据...
# 【CGPTUSDT】获取到 315 条记录
#
# 正在采集 HIVEUSDT 的全历史资金费率数据...
# 【HIVEUSDT】获取到 299 条记录
#
# 正在采集 DEXEUSDT 的全历史资金费率数据...
# 【DEXEUSDT】获取到 293 条记录
#
# 正在采集 PHAUSDT 的全历史资金费率数据...
# 【PHAUSDT】获取到 257 条记录
#
# 正在采集 DFUSDT 的全历史资金费率数据...
# 【DFUSDT】获取到 257 条记录
#
# 正在采集 GRIFFAINUSDT 的全历史资金费率数据...
# 【GRIFFAINUSDT】获取到 238 条记录
#
# 正在采集 AI16ZUSDT 的全历史资金费率数据...
# 【AI16ZUSDT】获取到 238 条记录
#
# 正在采集 ZEREBROUSDT 的全历史资金费率数据...
# 【ZEREBROUSDT】获取到 238 条记录
#
# 正在采集 BIOUSDT 的全历史资金费率数据...
# 【BIOUSDT】获取到 232 条记录
#
# 正在采集 COOKIEUSDT 的全历史资金费率数据...
# 【COOKIEUSDT】获取到 209 条记录
#
# 正在采集 ALCHUSDT 的全历史资金费率数据...
# 【ALCHUSDT】获取到 209 条记录
#
# 正在采集 SWARMSUSDT 的全历史资金费率数据...
# 【SWARMSUSDT】获取到 208 条记录
#
# 正在采集 SONICUSDT 的全历史资金费率数据...
# 【SONICUSDT】获取到 204 条记录
#
# 正在采集 DUSDT 的全历史资金费率数据...
# 【DUSDT】获取到 197 条记录
#
# 正在采集 PROMUSDT 的全历史资金费率数据...
# 【PROMUSDT】获取到 160 条记录
#
# 正在采集 SUSDT 的全历史资金费率数据...
# 【SUSDT】获取到 155 条记录
#
# 正在采集 SOLVUSDT 的全历史资金费率数据...
# 【SOLVUSDT】获取到 148 条记录
#
# 正在采集 ARCUSDT 的全历史资金费率数据...
# 【ARCUSDT】获取到 148 条记录
#
# 正在采集 AVAAIUSDT 的全历史资金费率数据...
# 【AVAAIUSDT】获取到 148 条记录
#
# 正在采集 TRUMPUSDT 的全历史资金费率数据...
# 【TRUMPUSDT】获取到 142 条记录
#
# 正在采集 MELANIAUSDT 的全历史资金费率数据...
# 【MELANIAUSDT】获取到 131 条记录
#
# 正在采集 VTHOUSDT 的全历史资金费率数据...
# 【VTHOUSDT】获取到 119 条记录
#
# 正在采集 ANIMEUSDT 的全历史资金费率数据...
# 【ANIMEUSDT】获取到 111 条记录
#
# 正在采集 VINEUSDT 的全历史资金费率数据...
# 【VINEUSDT】获取到 107 条记录
#
# 正在采集 PIPPINUSDT 的全历史资金费率数据...
# 【PIPPINUSDT】获取到 107 条记录
#
# 正在采集 VVVUSDT 的全历史资金费率数据...
# 【VVVUSDT】获取到 78 条记录
#
# 正在采集 BERAUSDT 的全历史资金费率数据...
# 【BERAUSDT】获取到 28 条记录
#
# 正在采集 TSTUSDT 的全历史资金费率数据...
# 【TSTUSDT】获取到 10 条记录

# %% [markdown]
# # 3 将数据保存为 CSV 文件，方便后续在 Notebook 中加载分析

# %%
df = pd.DataFrame(all_funding_data)
csv_filename = "binance_funding_rate_history_full.csv"
df.to_csv(csv_filename, index=False)
print(f"\n所有数据已保存到文件：{csv_filename}")
# Out:
# 所有数据已保存到文件：binance_funding_rate_history_full.csv
